# %%
import pandas as pd
import pyomo.environ as pyo

# %%
# Helper functions
def read_vehicle_cost(file_path):
    """
    This function reads the vehicle cost from the file and returns a dictionary of vehicle cost

    parameters: file_path: str: path to the file containing the vehicle cost
    """
    if file_path is None:
        raise ValueError("file_path cannot be None")
    
    data = pd.read_csv(file_path)
    vehicle_cost = {}
    for _, row in data.iterrows():
        vehicle_cost[row["ID"]] = row["Cost ($)"]

    return vehicle_cost

# %%
# Data

purchased_cost_data = read_vehicle_cost("dataset/vehicles.csv")

# %%
# Model

model = pyo.ConcreteModel()

model.years = pyo.Set(initialize = range(2023, 2039))
model.vehicle_types = pyo.Set(initialize = purchased_cost_data.keys())
model.size_buckets = pyo.Set(initialize = ["S1", "S2", "S3", "S4"])
model.distance_buckets = pyo.Set(initialize = ["D1", "D2", "D3", "D4"])
model.fuel_types = pyo.Set(initialize = ["Electricity", "B20", "LNG", "BioLNG", "HVO"])

# %%
model.C_buy = pyo.Param(model.vehicle_types, initialize = purchased_cost_data, within = pyo.NonNegativeReals)

# %%
def read_vehicle_range(file_path):
    """
    This function reads the vehicle range from the file and returns a dictionary of vehicle range

    parameters: file_path: str: path to the file containing the vehicle range
    """
    if file_path is None:
        raise ValueError("file_path cannot be None")
    
    data = pd.read_csv(file_path)
    vehicle_range = {}
    for _, row in data.iterrows():
        vehicle_range[row["ID"]] = row["Yearly range (km)"]

    return vehicle_range

# %%
vehicle_range_data = read_vehicle_range("dataset/vehicles.csv")

# %%
def read_fuel_cost(file_path):
    """
    This function reads the fuel cost from the file and returns a dictionary of fuel cost

    parameters: file_path: str: path to the file containing the fuel cost
    """
    if file_path is None:
        raise ValueError("file_path cannot be None")
    
    data = pd.read_csv(file_path)
    fuel_cost = {}
    for _, row in data.iterrows():
        key = f"{row['Fuel']}_{int(row['Year'])}"
        fuel_cost[key] = float(row["Cost ($/unit_fuel)"])

    return fuel_cost

# %%
fuel_cost_data = read_fuel_cost("dataset/fuels.csv")

# %%
model.fuel_cost = pyo.Param(model.fuel_types, model.years, initialize = lambda model, f, y: fuel_cost_data[f"{f}_{y}"], within = pyo.NonNegativeReals)

# %%
def read_fuel_consumption(file_path):
    """
    This function reads the fuel consumption from the file and returns a dictionary of fuel consumption

    parameters: file_path: str: path to the file containing the fuel consumption
    """
    data = pd.read_csv(file_path)
    fuel_consumption = {}
    for _, row in data.iterrows():
        fuel_consumption[row["ID"]] = row["Consumption (unit_fuel/km)"]

    return fuel_consumption

# %%
fuel_consumption_data = read_fuel_consumption("dataset/vehicles_fuels.csv")

# %%
model.fuel_consumption = pyo.Param(model.vehicle_types, initialize = fuel_consumption_data, within = pyo.NonNegativeReals)

# %%
model.fuel_consumption.pprint()
# Out:
# fuel_consumption : Size=192, Index=vehicle_types, Domain=NonNegativeReals, Default=None, Mutable=False
#     Key            : Value
#        BEV_S1_2023 : 0.893043
#        BEV_S1_2024 : 0.893043
#        BEV_S1_2025 : 0.893043
#        BEV_S1_2026 : 0.893043
#        BEV_S1_2027 : 0.868161
#        BEV_S1_2028 : 0.868161
#        BEV_S1_2029 : 0.868161
#        BEV_S1_2030 : 0.868161
#        BEV_S1_2031 : 0.868161
#        BEV_S1_2032 : 0.868161
#        BEV_S1_2033 : 0.868161
#        BEV_S1_2034 : 0.868161
#        BEV_S1_2035 : 0.868161
#        BEV_S1_2036 : 0.868161
#        BEV_S1_2037 : 0.868161
#        BEV_S1_2038 : 0.868161
#        BEV_S2_2023 :   0.8968
#        BEV_S2_2024 :   0.8968
#        BEV_S2_2025 :   0.8968
#        BEV_S2_2026 :   0.8968
#        BEV_S2_2027 :  0.85459
#        BEV_S2_2028 :  0.85459
#        BEV_S2_2029 :  0.85459
#        BEV_S2_2030 :  0.85459
#        BEV_S2_2031 :  0.85459
#        BEV_S2_2032 :  0.85459
#        BEV_S2_2033 :  0.85459
#        BEV_S2_2034 :  0.85459
#        BEV_S2_2035 :  0.85459
#        BEV_S2_2036 :  0.85459
#        BEV_S2_2037 :  0.85459
#        BEV_S2_2038 :  0.85459
#        BEV_S3_2023 : 0.898003
#        BEV_S3_2024 : 0.898003
#        BEV_S3_2025 : 0.898003
#        BEV_S3_2026 : 0.898003
#        BEV_S3_2027 : 0.859516
#        BEV_S3_2028 : 0.859516
#        BEV_S3_2029 : 0.859516
#        BEV_S3_2030 : 0.859516
#        BEV_S3_2031 : 0.859516
#        BEV_S3_2032 : 0.859516
#        BEV_S3_2033 : 0.859516
#        BEV_S3_2034 : 0.859516
#        BEV_S3_2035 : 0.859516
#        BEV_S3_2036 : 0.859516
#        BEV_S3_2037 : 0.859516
#        BEV_S3_2038 : 0.859516
#        BEV_S4_2023 : 0.900664
#        BEV_S4_2024 : 0.900664
#        BEV_S4_2025 : 0.900664
#        BEV_S4_2026 : 0.900664
#        BEV_S4_2027 : 0.856448
#        BEV_S4_2028 : 0.856448
#        BEV_S4_2029 : 0.856448
#        BEV_S4_2030 : 0.856448
#        BEV_S4_2031 : 0.856448
#        BEV_S4_2032 : 0.856448
#        BEV_S4_2033 : 0.856448
#        BEV_S4_2034 : 0.856448
#        BEV_S4_2035 : 0.856448
#        BEV_S4_2036 : 0.856448
#        BEV_S4_2037 : 0.856448
#        BEV_S4_2038 : 0.856448
#     Diesel_S1_2023 : 0.223016
#     Diesel_S1_2024 : 0.223016
#     Diesel_S1_2025 : 0.223016
#     Diesel_S1_2026 : 0.223016
#     Diesel_S1_2027 : 0.223016
#     Diesel_S1_2028 : 0.223016
#     Diesel_S1_2029 : 0.223016
#     Diesel_S1_2030 : 0.223016
#     Diesel_S1_2031 : 0.223016
#     Diesel_S1_2032 : 0.223016
#     Diesel_S1_2033 : 0.223016
#     Diesel_S1_2034 : 0.223016
#     Diesel_S1_2035 : 0.223016
#     Diesel_S1_2036 : 0.223016
#     Diesel_S1_2037 : 0.223016
#     Diesel_S1_2038 : 0.223016
#     Diesel_S2_2023 : 0.223852
#     Diesel_S2_2024 : 0.223852
#     Diesel_S2_2025 : 0.223852
#     Diesel_S2_2026 : 0.223852
#     Diesel_S2_2027 : 0.223852
#     Diesel_S2_2028 : 0.223852
#     Diesel_S2_2029 : 0.223852
#     Diesel_S2_2030 : 0.223852
#     Diesel_S2_2031 : 0.223852
#     Diesel_S2_2032 : 0.223852
#     Diesel_S2_2033 : 0.223852
#     Diesel_S2_2034 : 0.223852
#     Diesel_S2_2035 : 0.223852
#     Diesel_S2_2036 : 0.223852
#     Diesel_S2_2037 : 0.223852
#     Diesel_S2_2038 : 0.223852
#     Diesel_S3_2023 : 0.224082
#     Diesel_S3_2024 : 0.224082
#     Diesel_S3_2025 : 0.224082
#     Diesel_S3_2026 : 0.224082
#     Diesel_S3_2027 : 0.224082
#     Diesel_S3_2028 : 0.224082
#     Diesel_S3_2029 : 0.224082
#     Diesel_S3_2030 : 0.224082
#     Diesel_S3_2031 : 0.224082
#     Diesel_S3_2032 : 0.224082
#     Diesel_S3_2033 : 0.224082
#     Diesel_S3_2034 : 0.224082
#     Diesel_S3_2035 : 0.224082
#     Diesel_S3_2036 : 0.224082
#     Diesel_S3_2037 : 0.224082
#     Diesel_S3_2038 : 0.224082
#     Diesel_S4_2023 : 0.219827
#     Diesel_S4_2024 : 0.219827
#     Diesel_S4_2025 : 0.219827
#     Diesel_S4_2026 : 0.219827
#     Diesel_S4_2027 : 0.219827
#     Diesel_S4_2028 : 0.219827
#     Diesel_S4_2029 : 0.219827
#     Diesel_S4_2030 : 0.219827
#     Diesel_S4_2031 : 0.219827
#     Diesel_S4_2032 : 0.219827
#     Diesel_S4_2033 : 0.219827
#     Diesel_S4_2034 : 0.219827
#     Diesel_S4_2035 : 0.219827
#     Diesel_S4_2036 : 0.219827
#     Diesel_S4_2037 : 0.219827
#     Diesel_S4_2038 : 0.219827
#        LNG_S1_2023 : 0.165159
#        LNG_S1_2024 : 0.165159
#        LNG_S1_2025 : 0.165159
#        LNG_S1_2026 :   0.1632
#        LNG_S1_2027 : 0.159467
#        LNG_S1_2028 :  0.15574
#        LNG_S1_2029 : 0.154381
#        LNG_S1_2030 : 0.154381
#        LNG_S1_2031 : 0.154381
#        LNG_S1_2032 : 0.154381
#        LNG_S1_2033 : 0.154381
#        LNG_S1_2034 : 0.154381
#        LNG_S1_2035 : 0.154381
#        LNG_S1_2036 : 0.154381
#        LNG_S1_2037 : 0.154381
#        LNG_S1_2038 : 0.154381
#        LNG_S2_2023 : 0.167185
#        LNG_S2_2024 : 0.167185
#        LNG_S2_2025 : 0.167185
#        LNG_S2_2026 : 0.164643
#        LNG_S2_2027 : 0.161171
#        LNG_S2_2028 : 0.158367
#        LNG_S2_2029 : 0.155039
#        LNG_S2_2030 : 0.155039
#        LNG_S2_2031 : 0.155039
#        LNG_S2_2032 : 0.155039
#        LNG_S2_2033 : 0.155039
#        LNG_S2_2034 : 0.155039
#        LNG_S2_2035 : 0.155039
#        LNG_S2_2036 : 0.155039
#        LNG_S2_2037 : 0.155039
#        LNG_S2_2038 : 0.155039
#        LNG_S3_2023 : 0.164684
#        LNG_S3_2024 : 0.164684
#        LNG_S3_2025 : 0.164684
#        LNG_S3_2026 : 0.164223
#        LNG_S3_2027 : 0.160634
#        LNG_S3_2028 : 0.155696
#        LNG_S3_2029 : 0.155192
#        LNG_S3_2030 : 0.155192
#        LNG_S3_2031 : 0.155192
#        LNG_S3_2032 : 0.155192
#        LNG_S3_2033 : 0.155192
#        LNG_S3_2034 : 0.155192
#        LNG_S3_2035 : 0.155192
#        LNG_S3_2036 : 0.155192
#        LNG_S3_2037 : 0.155192
#        LNG_S3_2038 : 0.155192
#        LNG_S4_2023 : 0.166088
#        LNG_S4_2024 : 0.166088
#        LNG_S4_2025 : 0.166088
#        LNG_S4_2026 : 0.164154
#        LNG_S4_2027 : 0.160223
#        LNG_S4_2028 : 0.155978
#        LNG_S4_2029 : 0.154568
#        LNG_S4_2030 : 0.154568
#        LNG_S4_2031 : 0.154568
#        LNG_S4_2032 : 0.154568
#        LNG_S4_2033 : 0.154568
#        LNG_S4_2034 : 0.154568
#        LNG_S4_2035 : 0.154568
#        LNG_S4_2036 : 0.154568
#        LNG_S4_2037 : 0.154568
#        LNG_S4_2038 : 0.154568

# %%
def read_fuel_emission_factors(file_path):
    """
    This function reads the fuel consumption from the file and returns a dictionary of fuel emissions

    parameters: file_path: str: path to the file containing the fuel consumption
    """
    data = pd.read_csv(file_path)
    emission_cost = {}
    for _,row in data.iterrows():
        key = f"{row["Fuel"]}_{int(row["Year"])}"
        emission_cost[key] = float(row["Emissions (CO2/unit_fuel)"])

    return emission_cost

# %%
emission_factor = read_fuel_emission_factors("dataset/fuels.csv")

# %%
model.emission_factor = pyo.Param(model.fuel_types, model.years, initialize = lambda model, f, y: emission_factor[f"{f}_{y}"], within = pyo.NonNegativeReals )

# %%
model.emission_factor.pprint()
# Out:
# emission_factor : Size=80, Index=fuel_types*years, Domain=NonNegativeReals, Default=None, Mutable=False
#     Key                   : Value
#             ('B20', 2023) :  3.04858
#             ('B20', 2024) :  3.04858
#             ('B20', 2025) :  3.04858
#             ('B20', 2026) :  3.04858
#             ('B20', 2027) :  3.04858
#             ('B20', 2028) :  3.04858
#             ('B20', 2029) :  3.04858
#             ('B20', 2030) :  3.04858
#             ('B20', 2031) :  3.04858
#             ('B20', 2032) :  3.04858
#             ('B20', 2033) :  3.04858
#             ('B20', 2034) :  3.04858
#             ('B20', 2035) :  3.04858
#             ('B20', 2036) :  3.04858
#             ('B20', 2037) :  3.04858
#             ('B20', 2038) :  3.04858
#          ('BioLNG', 2023) : 0.378439
#          ('BioLNG', 2024) : 0.378439
#          ('BioLNG', 2025) : 0.378439
#          ('BioLNG', 2026) : 0.378439
#          ('BioLNG', 2027) : 0.378439
#          ('BioLNG', 2028) : 0.378439
#          ('BioLNG', 2029) : 0.378439
#          ('BioLNG', 2030) : 0.378439
#          ('BioLNG', 2031) : 0.378439
#          ('BioLNG', 2032) : 0.378439
#          ('BioLNG', 2033) : 0.378439
#          ('BioLNG', 2034) : 0.378439
#          ('BioLNG', 2035) : 0.378439
#          ('BioLNG', 2036) : 0.378439
#          ('BioLNG', 2037) : 0.378439
#          ('BioLNG', 2038) : 0.378439
#     ('Electricity', 2023) :      0.0
#     ('Electricity', 2024) :      0.0
#     ('Electricity', 2025) :      0.0
#     ('Electricity', 2026) :      0.0
#     ('Electricity', 2027) :      0.0
#     ('Electricity', 2028) :      0.0
#     ('Electricity', 2029) :      0.0
#     ('Electricity', 2030) :      0.0
#     ('Electricity', 2031) :      0.0
#     ('Electricity', 2032) :      0.0
#     ('Electricity', 2033) :      0.0
#     ('Electricity', 2034) :      0.0
#     ('Electricity', 2035) :      0.0
#     ('Electricity', 2036) :      0.0
#     ('Electricity', 2037) :      0.0
#     ('Electricity', 2038) :      0.0
#             ('HVO', 2023) : 0.487624
#             ('HVO', 2024) : 0.487624
#             ('HVO', 2025) : 0.487624
#             ('HVO', 2026) : 0.487624
#             ('HVO', 2027) : 0.487624
#             ('HVO', 2028) : 0.487624
#             ('HVO', 2029) : 0.487624
#             ('HVO', 2030) : 0.487624
#             ('HVO', 2031) : 0.487624
#             ('HVO', 2032) : 0.487624
#             ('HVO', 2033) : 0.487624
#             ('HVO', 2034) : 0.487624
#             ('HVO', 2035) : 0.487624
#             ('HVO', 2036) : 0.487624
#             ('HVO', 2037) : 0.487624
#             ('HVO', 2038) : 0.487624
#             ('LNG', 2023) : 2.486188
#             ('LNG', 2024) : 2.486188
#             ('LNG', 2025) : 2.486188
#             ('LNG', 2026) : 2.486188
#             ('LNG', 2027) : 2.486188
#             ('LNG', 2028) : 2.486188
#             ('LNG', 2029) : 2.486188
#             ('LNG', 2030) : 2.486188
#             ('LNG', 2031) : 2.486188
#             ('LNG', 2032) : 2.486188
#             ('LNG', 2033) : 2.486188
#             ('LNG', 2034) : 2.486188
#             ('LNG', 2035) : 2.486188
#             ('LNG', 2036) : 2.486188
#             ('LNG', 2037) : 2.486188
#             ('LNG', 2038) : 2.486188

# %%
def read_demand(file_path):
    """
    This function reads the demand of cars from the file and returns a dict of demand in Km

    parameters: file_path: str: path to file the containing the demand of the cars
    """
    data = pd.read_csv(file_path)
    demand = {}
    for _, row in data.iterrows():
        key = f"{int(row["Year"])}_{row["Size"]}_{row["Distance"]}"
        demand[key] = row["Demand (km)"]

    return demand

# %%
demand_data = read_demand("dataset/demand.csv")

# %%
demand_data
# Out:
# {'2023_S1_D1': 869181,
#  '2023_S1_D2': 2597094,
#  '2023_S1_D3': 3292011,
#  '2023_S1_D4': 414315,
#  '2023_S2_D1': 995694,
#  '2023_S2_D2': 1383196,
#  '2023_S2_D3': 778008,
#  '2023_S2_D4': 133677,
#  '2023_S4_D1': 14576,
#  '2023_S4_D2': 754717,
#  '2023_S4_D3': 118899,
#  '2023_S4_D4': 1809,
#  '2023_S3_D1': 2183475,
#  '2023_S3_D2': 2431901,
#  '2023_S3_D3': 1002466,
#  '2023_S3_D4': 205426,
#  '2024_S1_D1': 877242,
#  '2024_S1_D2': 2716195,
#  '2024_S1_D3': 3336604,
#  '2024_S1_D4': 419981,
#  '2024_S2_D1': 1043209,
#  '2024_S2_D2': 1391987,
#  '2024_S2_D3': 807076,
#  '2024_S2_D4': 133712,
#  '2024_S4_D1': 15200,
#  '2024_S4_D2': 780979,
#  '2024_S4_D3': 122186,
#  '2024_S4_D4': 1893,
#  '2024_S3_D1': 2239440,
#  '2024_S3_D2': 2453497,
#  '2024_S3_D3': 1029375,
#  '2024_S3_D4': 208440,
#  '2025_S1_D1': 877707,
#  '2025_S1_D2': 2836223,
#  '2025_S1_D3': 3446113,
#  '2025_S1_D4': 439767,
#  '2025_S2_D1': 1082065,
#  '2025_S2_D2': 1410584,
#  '2025_S2_D3': 821678,
#  '2025_S2_D4': 137231,
#  '2025_S4_D1': 15615,
#  '2025_S4_D2': 791079,
#  '2025_S4_D3': 123252,
#  '2025_S4_D4': 1927,
#  '2025_S3_D1': 2255136,
#  '2025_S3_D2': 2501227,
#  '2025_S3_D3': 1053662,
#  '2025_S3_D4': 218537,
#  '2026_S1_D1': 884095,
#  '2026_S1_D2': 2909150,
#  '2026_S1_D3': 3537030,
#  '2026_S1_D4': 446478,
#  '2026_S2_D1': 1090703,
#  '2026_S2_D2': 1452683,
#  '2026_S2_D3': 825939,
#  '2026_S2_D4': 141128,
#  '2026_S4_D1': 15916,
#  '2026_S4_D2': 794430,
#  '2026_S4_D3': 126715,
#  '2026_S4_D4': 1989,
#  '2026_S3_D1': 2329773,
#  '2026_S3_D2': 2524893,
#  '2026_S3_D3': 1103927,
#  '2026_S3_D4': 219181,
#  '2027_S1_D1': 923004,
#  '2027_S1_D2': 3023153,
#  '2027_S1_D3': 3581681,
#  '2027_S1_D4': 467174,
#  '2027_S2_D1': 1114957,
#  '2027_S2_D2': 1480077,
#  '2027_S2_D3': 862851,
#  '2027_S2_D4': 146448,
#  '2027_S4_D1': 16532,
#  '2027_S4_D2': 829347,
#  '2027_S4_D3': 129765,
#  '2027_S4_D4': 2019,
#  '2027_S3_D1': 2381369,
#  '2027_S3_D2': 2591566,
#  '2027_S3_D3': 1137494,
#  '2027_S3_D4': 224937,
#  '2028_S1_D1': 968137,
#  '2028_S1_D2': 3114155,
#  '2028_S1_D3': 3731269,
#  '2028_S1_D4': 469168,
#  '2028_S2_D1': 1142178,
#  '2028_S2_D2': 1546703,
#  '2028_S2_D3': 902415,
#  '2028_S2_D4': 148036,
#  '2028_S4_D1': 16863,
#  '2028_S4_D2': 851953,
#  '2028_S4_D3': 133929,
#  '2028_S4_D4': 2066,
#  '2028_S3_D1': 2448472,
#  '2028_S3_D2': 2667924,
#  '2028_S3_D3': 1155329,
#  '2028_S3_D4': 233462,
#  '2029_S1_D1': 1009629,
#  '2029_S1_D2': 3188349,
#  '2029_S1_D3': 3892298,
#  '2029_S1_D4': 484671,
#  '2029_S2_D1': 1173616,
#  '2029_S2_D2': 1608555,
#  '2029_S2_D3': 916617,
#  '2029_S2_D4': 148322,
#  '2029_S4_D1': 17544,
#  '2029_S4_D2': 885863,
#  '2029_S4_D3': 135803,
#  '2029_S4_D4': 2113,
#  '2029_S3_D1': 2497153,
#  '2029_S3_D2': 2795108,
#  '2029_S3_D3': 1175528,
#  '2029_S3_D4': 234155,
#  '2030_S1_D1': 1009798,
#  '2030_S1_D2': 3285854,
#  '2030_S1_D3': 3959514,
#  '2030_S1_D4': 496273,
#  '2030_S2_D1': 1231293,
#  '2030_S2_D2': 1624238,
#  '2030_S2_D3': 931478,
#  '2030_S2_D4': 155565,
#  '2030_S4_D1': 18168,
#  '2030_S4_D2': 919290,
#  '2030_S4_D3': 136344,
#  '2030_S4_D4': 2114,
#  '2030_S3_D1': 2518188,
#  '2030_S3_D2': 2800498,
#  '2030_S3_D3': 1216569,
#  '2030_S3_D4': 240767,
#  '2031_S1_D1': 1042251,
#  '2031_S1_D2': 3310718,
#  '2031_S1_D3': 4061449,
#  '2031_S1_D4': 518651,
#  '2031_S2_D1': 1240402,
#  '2031_S2_D2': 1689196,
#  '2031_S2_D3': 943472,
#  '2031_S2_D4': 161977,
#  '2031_S4_D1': 18747,
#  '2031_S4_D2': 941960,
#  '2031_S4_D3': 139696,
#  '2031_S4_D4': 2198,
#  '2031_S3_D1': 2619164,
#  '2031_S3_D2': 2814164,
#  '2031_S3_D3': 1234148,
#  '2031_S3_D4': 242813,
#  '2032_S1_D1': 1069740,
#  '2032_S1_D2': 3430934,
#  '2032_S1_D3': 4237026,
#  '2032_S1_D4': 542921,
#  '2032_S2_D1': 1257890,
#  '2032_S2_D2': 1759215,
#  '2032_S2_D3': 980430,
#  '2032_S2_D4': 163126,
#  '2032_S4_D1': 19298,
#  '2032_S4_D2': 967461,
#  '2032_S4_D3': 141391,
#  '2032_S4_D4': 2230,
#  '2032_S3_D1': 2708133,
#  '2032_S3_D2': 2863674,
#  '2032_S3_D3': 1254261,
#  '2032_S3_D4': 250479,
#  '2033_S1_D1': 1070915,
#  '2033_S1_D2': 3491886,
#  '2033_S1_D3': 4290083,
#  '2033_S1_D4': 563313,
#  '2033_S2_D1': 1283026,
#  '2033_S2_D2': 1790314,
#  '2033_S2_D3': 1007259,
#  '2033_S2_D4': 168141,
#  '2033_S4_D1': 19951,
#  '2033_S4_D2': 1013174,
#  '2033_S4_D3': 146270,
#  '2033_S4_D4': 2236,
#  '2033_S3_D1': 2820991,
#  '2033_S3_D2': 2974170,
#  '2033_S3_D3': 1270139,
#  '2033_S3_D4': 262313,
#  '2034_S1_D1': 1080198,
#  '2034_S1_D2': 3606840,
#  '2034_S1_D3': 4474763,
#  '2034_S1_D4': 575445,
#  '2034_S2_D1': 1344795,
#  '2034_S2_D2': 1869435,
#  '2034_S2_D3': 1043936,
#  '2034_S2_D4': 169472,
#  '2034_S4_D1': 20807,
#  '2034_S4_D2': 1057133,
#  '2034_S4_D3': 146333,
#  '2034_S4_D4': 2280,
#  '2034_S3_D1': 2832153,
#  '2034_S3_D2': 3096840,
#  '2034_S3_D3': 1320768,
#  '2034_S3_D4': 273053,
#  '2035_S1_D1': 1106719,
#  '2035_S1_D2': 3746146,
#  '2035_S1_D3': 4476447,
#  '2035_S1_D4': 588196,
#  '2035_S2_D1': 1350533,
#  '2035_S2_D2': 1934621,
#  '2035_S2_D3': 1053870,
#  '2035_S2_D4': 176929,
#  '2035_S4_D1': 21666,
#  '2035_S4_D2': 1107787,
#  '2035_S4_D3': 147590,
#  '2035_S4_D4': 2369,
#  '2035_S3_D1': 2908543,
#  '2035_S3_D2': 3247401,
#  '2035_S3_D3': 1360337,
#  '2035_S3_D4': 274741,
#  '2036_S1_D1': 1143702,
#  '2036_S1_D2': 3821393,
#  '2036_S1_D3': 4599217,
#  '2036_S1_D4': 602557,
#  '2036_S2_D1': 1388729,
#  '2036_S2_D2': 1982301,
#  '2036_S2_D3': 1103197,
#  '2036_S2_D4': 180140,
#  '2036_S4_D1': 22740,
#  '2036_S4_D2': 1134238,
#  '2036_S4_D3': 151090,
#  '2036_S4_D4': 2412,
#  '2036_S3_D1': 2983351,
#  '2036_S3_D2': 3269872,
#  '2036_S3_D3': 1377326,
#  '2036_S3_D4': 280914,
#  '2037_S1_D1': 1196265,
#  '2037_S1_D2': 3953052,
#  '2037_S1_D3': 4663966,
#  '2037_S1_D4': 630092,
#  '2037_S2_D1': 1402031,
#  '2037_S2_D2': 2079105,
#  '2037_S2_D3': 1131832,
#  '2037_S2_D4': 186733,
#  '2037_S4_D1': 23254,
#  '2037_S4_D2': 1146520,
#  '2037_S4_D3': 156518,
#  '2037_S4_D4': 2414,
#  '2037_S3_D1': 3128820,
#  '2037_S3_D2': 3274991,
#  '2037_S3_D3': 1384988,
#  '2037_S3_D4': 292856,
#  '2038_S1_D1': 1254358,
#  '2038_S1_D2': 3994169,
#  '2038_S1_D3': 4847871,
#  '2038_S1_D4': 642216,
#  '2038_S2_D1': 1410693,
#  '2038_S2_D2': 2151804,
#  '2038_S2_D3': 1187938,
#  '2038_S2_D4': 190889,
#  '2038_S4_D1': 23437,
#  '2038_S4_D2': 1148555,
#  '2038_S4_D3': 161386,
#  '2038_S4_D4': 2446,
#  '2038_S3_D1': 3229278,
#  '2038_S3_D2': 3297618,
#  '2038_S3_D3': 1448550,
#  '2038_S3_D4': 306910}

# %%
model.demand = pyo.Param(model.years, model.size_buckets, model.distance_buckets, initialize = lambda model,y, s, d: demand_data[f"{y}_{s}_{d}"], within = pyo.NonNegativeReals)

# %%
model.demand.pprint()
# Out:
# demand : Size=256, Index=years*size_buckets*distance_buckets, Domain=NonNegativeReals, Default=None, Mutable=False
#     Key                : Value
#     (2023, 'S1', 'D1') :  869181
#     (2023, 'S1', 'D2') : 2597094
#     (2023, 'S1', 'D3') : 3292011
#     (2023, 'S1', 'D4') :  414315
#     (2023, 'S2', 'D1') :  995694
#     (2023, 'S2', 'D2') : 1383196
#     (2023, 'S2', 'D3') :  778008
#     (2023, 'S2', 'D4') :  133677
#     (2023, 'S3', 'D1') : 2183475
#     (2023, 'S3', 'D2') : 2431901
#     (2023, 'S3', 'D3') : 1002466
#     (2023, 'S3', 'D4') :  205426
#     (2023, 'S4', 'D1') :   14576
#     (2023, 'S4', 'D2') :  754717
#     (2023, 'S4', 'D3') :  118899
#     (2023, 'S4', 'D4') :    1809
#     (2024, 'S1', 'D1') :  877242
#     (2024, 'S1', 'D2') : 2716195
#     (2024, 'S1', 'D3') : 3336604
#     (2024, 'S1', 'D4') :  419981
#     (2024, 'S2', 'D1') : 1043209
#     (2024, 'S2', 'D2') : 1391987
#     (2024, 'S2', 'D3') :  807076
#     (2024, 'S2', 'D4') :  133712
#     (2024, 'S3', 'D1') : 2239440
#     (2024, 'S3', 'D2') : 2453497
#     (2024, 'S3', 'D3') : 1029375
#     (2024, 'S3', 'D4') :  208440
#     (2024, 'S4', 'D1') :   15200
#     (2024, 'S4', 'D2') :  780979
#     (2024, 'S4', 'D3') :  122186
#     (2024, 'S4', 'D4') :    1893
#     (2025, 'S1', 'D1') :  877707
#     (2025, 'S1', 'D2') : 2836223
#     (2025, 'S1', 'D3') : 3446113
#     (2025, 'S1', 'D4') :  439767
#     (2025, 'S2', 'D1') : 1082065
#     (2025, 'S2', 'D2') : 1410584
#     (2025, 'S2', 'D3') :  821678
#     (2025, 'S2', 'D4') :  137231
#     (2025, 'S3', 'D1') : 2255136
#     (2025, 'S3', 'D2') : 2501227
#     (2025, 'S3', 'D3') : 1053662
#     (2025, 'S3', 'D4') :  218537
#     (2025, 'S4', 'D1') :   15615
#     (2025, 'S4', 'D2') :  791079
#     (2025, 'S4', 'D3') :  123252
#     (2025, 'S4', 'D4') :    1927
#     (2026, 'S1', 'D1') :  884095
#     (2026, 'S1', 'D2') : 2909150
#     (2026, 'S1', 'D3') : 3537030
#     (2026, 'S1', 'D4') :  446478
#     (2026, 'S2', 'D1') : 1090703
#     (2026, 'S2', 'D2') : 1452683
#     (2026, 'S2', 'D3') :  825939
#     (2026, 'S2', 'D4') :  141128
#     (2026, 'S3', 'D1') : 2329773
#     (2026, 'S3', 'D2') : 2524893
#     (2026, 'S3', 'D3') : 1103927
#     (2026, 'S3', 'D4') :  219181
#     (2026, 'S4', 'D1') :   15916
#     (2026, 'S4', 'D2') :  794430
#     (2026, 'S4', 'D3') :  126715
#     (2026, 'S4', 'D4') :    1989
#     (2027, 'S1', 'D1') :  923004
#     (2027, 'S1', 'D2') : 3023153
#     (2027, 'S1', 'D3') : 3581681
#     (2027, 'S1', 'D4') :  467174
#     (2027, 'S2', 'D1') : 1114957
#     (2027, 'S2', 'D2') : 1480077
#     (2027, 'S2', 'D3') :  862851
#     (2027, 'S2', 'D4') :  146448
#     (2027, 'S3', 'D1') : 2381369
#     (2027, 'S3', 'D2') : 2591566
#     (2027, 'S3', 'D3') : 1137494
#     (2027, 'S3', 'D4') :  224937
#     (2027, 'S4', 'D1') :   16532
#     (2027, 'S4', 'D2') :  829347
#     (2027, 'S4', 'D3') :  129765
#     (2027, 'S4', 'D4') :    2019
#     (2028, 'S1', 'D1') :  968137
#     (2028, 'S1', 'D2') : 3114155
#     (2028, 'S1', 'D3') : 3731269
#     (2028, 'S1', 'D4') :  469168
#     (2028, 'S2', 'D1') : 1142178
#     (2028, 'S2', 'D2') : 1546703
#     (2028, 'S2', 'D3') :  902415
#     (2028, 'S2', 'D4') :  148036
#     (2028, 'S3', 'D1') : 2448472
#     (2028, 'S3', 'D2') : 2667924
#     (2028, 'S3', 'D3') : 1155329
#     (2028, 'S3', 'D4') :  233462
#     (2028, 'S4', 'D1') :   16863
#     (2028, 'S4', 'D2') :  851953
#     (2028, 'S4', 'D3') :  133929
#     (2028, 'S4', 'D4') :    2066
#     (2029, 'S1', 'D1') : 1009629
#     (2029, 'S1', 'D2') : 3188349
#     (2029, 'S1', 'D3') : 3892298
#     (2029, 'S1', 'D4') :  484671
#     (2029, 'S2', 'D1') : 1173616
#     (2029, 'S2', 'D2') : 1608555
#     (2029, 'S2', 'D3') :  916617
#     (2029, 'S2', 'D4') :  148322
#     (2029, 'S3', 'D1') : 2497153
#     (2029, 'S3', 'D2') : 2795108
#     (2029, 'S3', 'D3') : 1175528
#     (2029, 'S3', 'D4') :  234155
#     (2029, 'S4', 'D1') :   17544
#     (2029, 'S4', 'D2') :  885863
#     (2029, 'S4', 'D3') :  135803
#     (2029, 'S4', 'D4') :    2113
#     (2030, 'S1', 'D1') : 1009798
#     (2030, 'S1', 'D2') : 3285854
#     (2030, 'S1', 'D3') : 3959514
#     (2030, 'S1', 'D4') :  496273
#     (2030, 'S2', 'D1') : 1231293
#     (2030, 'S2', 'D2') : 1624238
#     (2030, 'S2', 'D3') :  931478
#     (2030, 'S2', 'D4') :  155565
#     (2030, 'S3', 'D1') : 2518188
#     (2030, 'S3', 'D2') : 2800498
#     (2030, 'S3', 'D3') : 1216569
#     (2030, 'S3', 'D4') :  240767
#     (2030, 'S4', 'D1') :   18168
#     (2030, 'S4', 'D2') :  919290
#     (2030, 'S4', 'D3') :  136344
#     (2030, 'S4', 'D4') :    2114
#     (2031, 'S1', 'D1') : 1042251
#     (2031, 'S1', 'D2') : 3310718
#     (2031, 'S1', 'D3') : 4061449
#     (2031, 'S1', 'D4') :  518651
#     (2031, 'S2', 'D1') : 1240402
#     (2031, 'S2', 'D2') : 1689196
#     (2031, 'S2', 'D3') :  943472
#     (2031, 'S2', 'D4') :  161977
#     (2031, 'S3', 'D1') : 2619164
#     (2031, 'S3', 'D2') : 2814164
#     (2031, 'S3', 'D3') : 1234148
#     (2031, 'S3', 'D4') :  242813
#     (2031, 'S4', 'D1') :   18747
#     (2031, 'S4', 'D2') :  941960
#     (2031, 'S4', 'D3') :  139696
#     (2031, 'S4', 'D4') :    2198
#     (2032, 'S1', 'D1') : 1069740
#     (2032, 'S1', 'D2') : 3430934
#     (2032, 'S1', 'D3') : 4237026
#     (2032, 'S1', 'D4') :  542921
#     (2032, 'S2', 'D1') : 1257890
#     (2032, 'S2', 'D2') : 1759215
#     (2032, 'S2', 'D3') :  980430
#     (2032, 'S2', 'D4') :  163126
#     (2032, 'S3', 'D1') : 2708133
#     (2032, 'S3', 'D2') : 2863674
#     (2032, 'S3', 'D3') : 1254261
#     (2032, 'S3', 'D4') :  250479
#     (2032, 'S4', 'D1') :   19298
#     (2032, 'S4', 'D2') :  967461
#     (2032, 'S4', 'D3') :  141391
#     (2032, 'S4', 'D4') :    2230
#     (2033, 'S1', 'D1') : 1070915
#     (2033, 'S1', 'D2') : 3491886
#     (2033, 'S1', 'D3') : 4290083
#     (2033, 'S1', 'D4') :  563313
#     (2033, 'S2', 'D1') : 1283026
#     (2033, 'S2', 'D2') : 1790314
#     (2033, 'S2', 'D3') : 1007259
#     (2033, 'S2', 'D4') :  168141
#     (2033, 'S3', 'D1') : 2820991
#     (2033, 'S3', 'D2') : 2974170
#     (2033, 'S3', 'D3') : 1270139
#     (2033, 'S3', 'D4') :  262313
#     (2033, 'S4', 'D1') :   19951
#     (2033, 'S4', 'D2') : 1013174
#     (2033, 'S4', 'D3') :  146270
#     (2033, 'S4', 'D4') :    2236
#     (2034, 'S1', 'D1') : 1080198
#     (2034, 'S1', 'D2') : 3606840
#     (2034, 'S1', 'D3') : 4474763
#     (2034, 'S1', 'D4') :  575445
#     (2034, 'S2', 'D1') : 1344795
#     (2034, 'S2', 'D2') : 1869435
#     (2034, 'S2', 'D3') : 1043936
#     (2034, 'S2', 'D4') :  169472
#     (2034, 'S3', 'D1') : 2832153
#     (2034, 'S3', 'D2') : 3096840
#     (2034, 'S3', 'D3') : 1320768
#     (2034, 'S3', 'D4') :  273053
#     (2034, 'S4', 'D1') :   20807
#     (2034, 'S4', 'D2') : 1057133
#     (2034, 'S4', 'D3') :  146333
#     (2034, 'S4', 'D4') :    2280
#     (2035, 'S1', 'D1') : 1106719
#     (2035, 'S1', 'D2') : 3746146
#     (2035, 'S1', 'D3') : 4476447
#     (2035, 'S1', 'D4') :  588196
#     (2035, 'S2', 'D1') : 1350533
#     (2035, 'S2', 'D2') : 1934621
#     (2035, 'S2', 'D3') : 1053870
#     (2035, 'S2', 'D4') :  176929
#     (2035, 'S3', 'D1') : 2908543
#     (2035, 'S3', 'D2') : 3247401
#     (2035, 'S3', 'D3') : 1360337
#     (2035, 'S3', 'D4') :  274741
#     (2035, 'S4', 'D1') :   21666
#     (2035, 'S4', 'D2') : 1107787
#     (2035, 'S4', 'D3') :  147590
#     (2035, 'S4', 'D4') :    2369
#     (2036, 'S1', 'D1') : 1143702
#     (2036, 'S1', 'D2') : 3821393
#     (2036, 'S1', 'D3') : 4599217
#     (2036, 'S1', 'D4') :  602557
#     (2036, 'S2', 'D1') : 1388729
#     (2036, 'S2', 'D2') : 1982301
#     (2036, 'S2', 'D3') : 1103197
#     (2036, 'S2', 'D4') :  180140
#     (2036, 'S3', 'D1') : 2983351
#     (2036, 'S3', 'D2') : 3269872
#     (2036, 'S3', 'D3') : 1377326
#     (2036, 'S3', 'D4') :  280914
#     (2036, 'S4', 'D1') :   22740
#     (2036, 'S4', 'D2') : 1134238
#     (2036, 'S4', 'D3') :  151090
#     (2036, 'S4', 'D4') :    2412
#     (2037, 'S1', 'D1') : 1196265
#     (2037, 'S1', 'D2') : 3953052
#     (2037, 'S1', 'D3') : 4663966
#     (2037, 'S1', 'D4') :  630092
#     (2037, 'S2', 'D1') : 1402031
#     (2037, 'S2', 'D2') : 2079105
#     (2037, 'S2', 'D3') : 1131832
#     (2037, 'S2', 'D4') :  186733
#     (2037, 'S3', 'D1') : 3128820
#     (2037, 'S3', 'D2') : 3274991
#     (2037, 'S3', 'D3') : 1384988
#     (2037, 'S3', 'D4') :  292856
#     (2037, 'S4', 'D1') :   23254
#     (2037, 'S4', 'D2') : 1146520
#     (2037, 'S4', 'D3') :  156518
#     (2037, 'S4', 'D4') :    2414
#     (2038, 'S1', 'D1') : 1254358
#     (2038, 'S1', 'D2') : 3994169
#     (2038, 'S1', 'D3') : 4847871
#     (2038, 'S1', 'D4') :  642216
#     (2038, 'S2', 'D1') : 1410693
#     (2038, 'S2', 'D2') : 2151804
#     (2038, 'S2', 'D3') : 1187938
#     (2038, 'S2', 'D4') :  190889
#     (2038, 'S3', 'D1') : 3229278
#     (2038, 'S3', 'D2') : 3297618
#     (2038, 'S3', 'D3') : 1448550
#     (2038, 'S3', 'D4') :  306910
#     (2038, 'S4', 'D1') :   23437
#     (2038, 'S4', 'D2') : 1148555
#     (2038, 'S4', 'D3') :  161386
#     (2038, 'S4', 'D4') :    2446

# %%
def read_carbon_emission(file_path):
    """
    This function reads the carbon limits of each years 

    parameters: file_path: str: path to the file containing the carbon emissions
    """
    data = pd.read_csv(file_path)
    carbon_emission = {}
    for _, row in data.iterrows():
        carbon_emission[row["Year"]] = row["Carbon emission CO2/kg"]

    return carbon_emission

# %%
carbon_limit_data = read_carbon_emission("dataset/carbon_emissions.csv")

# %%
model.years.pprint()
# Out:
# years : Size=1, Index=None, Ordered=Insertion
#     Key  : Dimen : Domain : Size : Members
#     None :     1 :    Any :   16 : {2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038}

# %%
model.carbon_limit = pyo.Param(model.years, initialize = carbon_limit_data, within = pyo.NonNegativeReals)

# %%
def read_cost_profiles(file_path):
    """
    This function reads the resale value from and returns a dictinary

    parameter: file_path: str: path to the file containing the carbon emissions 
    """    
    if file_path is None:
        raise ValueError("file_path cannot be None")
    data = pd.read_csv(file_path)
    resale_value = {}
    insurance_cost = {}
    maintenance_cost = {}

    for _, row in data.iterrows():
        year = int(row['End of Year'])
        resale_value[year] = float(row['Resale Value %'])
        insurance_cost[year] = float(row['Insurance Cost %'])
        maintenance_cost[year] = float(row['Maintenance Cost %'])

    return resale_value, insurance_cost, maintenance_cost

# %%
resale_value_dict, insurance_cost_dict, maintenance_cost_dict = read_cost_profiles("dataset/cost_profiles.csv")

# %%
maintenance_cost_dict
# Out:
# {1: 1.0,
#  2: 3.0,
#  3: 5.0,
#  4: 7.0,
#  5: 9.0,
#  6: 11.0,
#  7: 13.0,
#  8: 15.0,
#  9: 17.0,
#  10: 19.0}

# %%
model.resale_value = pyo.Param(initialize=resale_value_dict, within=pyo.NonNegativeReals)
model.insurance_cost = pyo.Param(initialize=insurance_cost_dict, within=pyo.NonNegativeReals)
model.maintenance_cost = pyo.Param(initialize=maintenance_cost_dict, within=pyo.NonNegativeReals)
# Out:
# ERROR: Rule failed for Param 'resale_value' with index 1: KeyError: "Cannot
# treat the scalar component 'resale_value' as an indexed component"
# ERROR: Constructing component 'resale_value' from data=None failed:
#         KeyError: "Cannot treat the scalar component 'resale_value' as an
#         indexed component"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model.resale_value = pyo.Param(initialize=resale_value_dict, within=pyo.NonNegativeReals)
#       2 model.insurance_cost = pyo.Param(initialize=insurance_cost_dict, within=pyo.NonNegativeReals)
#       3 model.maintenance_cost = pyo.Param(initialize=maintenance_cost_dict, within=pyo.NonNegativeReals)
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\block.py:571, in BlockData.__setattr__(self, name, val)
#     566 if name not in self.__dict__:
#     567     if isinstance(val, Component):
#     568         #
#     569         # Pyomo components are added with the add_component method.
#     570         #
# --> 571         self.add_component(name, val)
#     572     else:
#     573         #
#     574         # Other Python objects are added with the standard __setattr__
#     575         # method.
#     576         #
#     577         super(BlockData, self).__setattr__(name, val)
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\block.py:1116, in BlockData.add_component(self, name, val)
#    1108     logger.debug(
#    1109         "Constructing %s '%s' on %s from data=%s",
#    1110         val.__class__.__name__,
#    (...)
#    1113         str(data),
#    1114     )
#    1115 try:
# -> 1116     val.construct(data)
#    1117 except:
#    1118     err = sys.exc_info()[1]
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\param.py:843, in Param.construct(self, data)
#     839 self._constructed = None
#     840 #
#     841 # Step #1: initialize data from rule value
#     842 #
# --> 843 self._construct_from_rule_using_setitem()
#     844 #
#     845 # Step #2: allow any user-specified (external) data to override
#     846 # the initialization
#     847 #
#     848 if data is not None:
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\indexed_component.py:768, in IndexedComponent._construct_from_rule_using_setitem(self)
#     765 if rule.contains_indices():
#     766     # The index is coming in externally; we need to validate it
#     767     for index in rule.indices():
# --> 768         self[index] = rule(block, index)
#     769 elif not self.index_set().isfinite():
#     770     # If the index is not finite, then we cannot iterate
#     771     # over it.  Since the rule doesn't provide explicit
#     772     # indices, then there is nothing we can do (the
#     773     # assumption is that the user will trigger specific
#     774     # indices to be created at a later time).
#     775     pass
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\indexed_component.py:688, in IndexedComponent.__setitem__(self, index, val)
#     683 if obj is _NotFound:
#     684     # If we didn't find the index in the data, then we need to
#     685     # validate it against the underlying set (as long as
#     686     # _processUnhashableIndex didn't return a slicer)
#     687     if index.__class__ is not IndexedComponent_slice:
# --> 688         index = self._validate_index(index)
#     689 else:
#     690     return self._setitem_impl(index, obj, val)
#
# File c:\Users\chidu\miniconda3\envs\shell\Lib\site-packages\pyomo\core\base\indexed_component.py:859, in IndexedComponent._validate_index(self, idx)
#     855 #
#     856 # Generate different errors, depending on the state of the index.
#     857 #
#     858 if not self.is_indexed():
# --> 859     raise KeyError(
#     860         "Cannot treat the scalar component '%s' "
#     861         "as an indexed component" % (self.name,)
#     862     )
#     863 #
#     864 # Raise an exception
#     865 #
#     866 raise KeyError(
#     867     "Index '%s' is not valid for indexed component '%s'"
#     868     % (normalized_idx, self.name)
#     869 )
#
# KeyError: "Cannot treat the scalar component 'resale_value' as an indexed component"
